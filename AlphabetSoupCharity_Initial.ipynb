# %% [markdown]
# ## Preprocessing the Data

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
df = pd.read_csv("../Resources/charity_data.csv")
df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df = df.drop("EIN", 1)
df = df.drop("NAME", 1)
df
# Out:
# C:\Users\Thissen\AppData\Local\Temp\ipykernel_8540\2684138810.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop("EIN", 1)
# C:\Users\Thissen\AppData\Local\Temp\ipykernel_8540\2684138810.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop("NAME", 1)
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#df['APPLICATION_TYPE'].value_counts()
application_counts = df['APPLICATION_TYPE'].value_counts()
application_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_counts[application_counts < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
# df['CLASSIFICATION'].value_counts()
class_counts = df['CLASSIFICATION'].value_counts()
class_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_count_1=class_counts[class_counts>1]
class_count_1
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_counts[class_counts < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    df['CLASSIFICATION'] = df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies_df = pd.get_dummies(df, drop_first = True)
dummies_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  \
# 0           1      5000              1                     1
# 1           1    108590              1                     0
# 2           1      5000              0                     0
# 3           1      6692              1                     0
# 4           1    142590              1                     0
# ...       ...       ...            ...                   ...
# 34294       1      5000              0                     0
# 34295       1      5000              0                     0
# 34296       1      5000              0                     0
# 34297       1      5000              1                     0
# 34298       1  36500179              0                     0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                         0                    0                    0
# 1                         0                    1                    0
# 2                         0                    0                    0
# 3                         0                    1                    0
# 4                         0                    1                    0
# ...                     ...                  ...                  ...
# 34294                     0                    0                    1
# 34295                     0                    0                    1
# 34296                     0                    1                    0
# 34297                     0                    0                    0
# 34298                     0                    1                    0
#
#        APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        1                    0                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    0                    0                    0  ...
# 34295                    0                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    1                    0                    0  ...
# 34298                    0                    0                    0  ...
#
#        ORGANIZATION_Trust  INCOME_AMT_1-9999  INCOME_AMT_10000-24999  \
# 0                       0                  0                       0
# 1                       0                  1                       0
# 2                       0                  0                       0
# 3                       1                  0                       1
# 4                       1                  0                       0
# ...                   ...                ...                     ...
# 34294                   0                  0                       0
# 34295                   0                  0                       0
# 34296                   0                  0                       0
# 34297                   0                  0                       0
# 34298                   0                  0                       0
#
#        INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  \
# 0                             0                   0                 0
# 1                             0                   0                 0
# 2                             0                   0                 0
# 3                             0                   0                 0
# 4                             1                   0                 0
# ...                         ...                 ...               ...
# 34294                         0                   0                 0
# 34295                         0                   0                 0
# 34296                         0                   0                 0
# 34297                         0                   0                 0
# 34298                         0                   0                 1
#
#        INCOME_AMT_25000-99999  INCOME_AMT_50M+  INCOME_AMT_5M-10M  \
# 0                           0                0                  0
# 1                           0                0                  0
# 2                           0                0                  0
# 3                           0                0                  0
# 4                           0                0                  0
# ...                       ...              ...                ...
# 34294                       0                0                  0
# 34295                       0                0                  0
# 34296                       0                0                  0
# 34297                       0                0                  0
# 34298                       0                0                  0
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 37 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = dummies_df.drop(["IS_SUCCESSFUL"], axis='columns').values
y = dummies_df["IS_SUCCESSFUL"].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=18, activation="relu", input_dim=len(X_train[0])))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=18, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 18)                666
#
#  dense_1 (Dense)             (None, 18)                342
#
#  dense_2 (Dense)             (None, 1)                 19
#
# =================================================================
# Total params: 1,027
# Trainable params: 1,027
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
from keras.callbacks import Callback

mc = tf.keras.callbacks.ModelCheckpoint('weights{epoch:08d}.h5', 
                                     save_weights_only=True, period=5)
    
        
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50, callbacks = [mc])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5928 - accuracy: 0.7081
# Epoch 2/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5612 - accuracy: 0.7279
# Epoch 3/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5560 - accuracy: 0.7304
# Epoch 4/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5538 - accuracy: 0.7301
# Epoch 5/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5521 - accuracy: 0.7309
# Epoch 6/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5513 - accuracy: 0.7317
# Epoch 7/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7325
# Epoch 8/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5496 - accuracy: 0.7310
# Epoch 9/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5485 - accuracy: 0.7317
# Epoch 10/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5483 - accuracy: 0.7323
# Epoch 11/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5483 - accuracy: 0.7322
# Epoch 12/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5477 - accuracy: 0.7328
# Epoch 13/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5474 - accuracy: 0.7341
# Epoch 14/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7346
# Epoch 15/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5468 - accuracy: 0.7338
# Epoch 16/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7336
# Epoch 17/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7343
# Epoch 18/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5455 - accuracy: 0.7349
# Epoch 19/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5457 - accuracy: 0.7344
# Epoch 20/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5452 - accuracy: 0.7329
# Epoch 21/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5452 - accuracy: 0.7350
# Epoch 22/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5450 - accuracy: 0.7353
# Epoch 23/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5453 - accuracy: 0.7357
# Epoch 24/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5449 - accuracy: 0.7348
# Epoch 25/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7352
# Epoch 26/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7357
# Epoch 27/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5444 - accuracy: 0.7355
# Epoch 28/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5442 - accuracy: 0.7355
# Epoch 29/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5441 - accuracy: 0.7369
# Epoch 30/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5434 - accuracy: 0.7369
# Epoch 31/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5440 - accuracy: 0.7357
# Epoch 32/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7365
# Epoch 33/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5437 - accuracy: 0.7363
# Epoch 34/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5431 - accuracy: 0.7361
# Epoch 35/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5431 - accuracy: 0.7352
# Epoch 36/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5435 - accuracy: 0.7361
# Epoch 37/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5431 - accuracy: 0.7360
# Epoch 38/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7372
# Epoch 39/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7359
# Epoch 40/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5430 - accuracy: 0.7365
# Epoch 41/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.7353
# Epoch 42/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5430 - accuracy: 0.7376
# Epoch 43/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5429 - accuracy: 0.7375
# Epoch 44/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5429 - accuracy: 0.7368
# Epoch 45/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5422 - accuracy: 0.7370
# Epoch 46/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5423 - accuracy: 0.7367
# Epoch 47/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5425 - accuracy: 0.7373
# Epoch 48/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5424 - accuracy: 0.7381
# Epoch 49/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5423 - accuracy: 0.7371
# Epoch 50/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5423 - accuracy: 0.7374

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5516 - accuracy: 0.7277 - 590ms/epoch - 2ms/step
# Loss: 0.5515628457069397, Accuracy: 0.7276967763900757

# %%
# Export our model to HDF5 file
nn_model.save("AlphabetSoupCharity.h5")
